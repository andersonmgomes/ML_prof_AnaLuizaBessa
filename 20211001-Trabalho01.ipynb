# %% [markdown]
# # <center>1ª Atividade de Aprendizado de Máquina</center>
# # <center>Análise de Dados</center>
# ### <center><b><i>Anderson Martins Gomes</i></b></center>
# ## <center>Programa de Pós-graduação em Ciência da Computação - PPGCC/UECE</center>
# ### <center><i>andersonmg@gmail.com</i></center>
#
# ## <center><b>Resumo</b></center>
# <p style="margin-left: 50px; margin-right: 50px; text-align: justify">Neste trabalho é apresentada a análise exploratória da base de dados <i>UCI Machine Learning Repository: Wine Quality Data Set</i>. Esse conjunto apresenta informações relacionadas à qualidade de vinhos brancos e tintos. Na análise, optou-se exclusivamente pelo subconjunto dos vinhos tintos. Foram utilizadas principalmente medidas estatísticas descritivas como a média, a variância e o desvio padrão. Utilizaram-se também gráficos, como <i>boxplots</i> e <i>scatter plots</i>, que permitiram a visualização dos dados em busca de seus padrões. Na análise descobriu-se que o atributo mais próximo de uma distribuição normal é o <i>density</i>, que apresentou um desvio padrão de 0.001887. Outra conclusão foi que a variável com correlação mais forte com o atributo <i>quality</i> foi a <i>alcohol</i>, com um índice de correlação igual a 0.476166. Por fim, considerando a variável <i>quality</i> como alvo de um futuro algoritmo de predição, identificou-se o atributo <i>fixed acidity</i> como mais forte candidato a ser descartado, em uma eventual redução de dimensionalidade, por conta de sua redundância em relação a outras variáveis independentes.</p>
#
#
# # <b>1 Introdução</b>
# <p style="text-align: justify; text-indent:50px;">Neste trabalho é apresentada a análise exploratória da base de dados <i>UCI Machine Learning Repository: Wine Quality Data Set</i>. Esse conjunto apresenta informações relacionadas à qualidade de vinhos brancos e tintos. Na análise foram utilizadas principalmente medidas estatísticas descritivas como a média, a variância e o desvio padrão. Utilizaram-se também gráficos, como <i>boxplots</i> e <i>scatter plots</i>, que permitiram a visualização dos dados em busca de seus padrões. Por fim, buscou-se responder as seguintes perguntas: <i>"que atributo está mais próximo de uma distribuição normal?"</i>; <i>"que variável está mais correlacionada com o atributo 'quality'?"</i>; <i>"considerando o atributo 'quality' como alvo, qual o par de variáveis independentes seria o melhor candidato ao descarte por serem redundantes?"</i>. Trabalho inserido no âmbito da disciplina de Aprendizado de Máquina, professora Ana Luiza Bessa, Programa de Pós-graduação em Ciência da Computação, Universidade Estadual do Ceará.</p>
#
# # <b>2 Análise de Dados</b>
# <p style="text-align: justify; text-indent:50px;">A Análise de Dados é fundamental para obtenção de boas soluções de Aprendizado de Máquina. Isso se dá por dois fatores básicos: a necessidade de limpeza e de compreensão dos dados. O processo de limpeza é genericamente definido como a etapa na qual o cientista de dados identifica e soluciona incompletudes, inconsistências, redundâncias ou ruídos nos dados brutos. Para cada um desse problemas há técnicas diferentes desenvolvidas para resolvê-los ou, no mínimo, mitigá-los, permitindo um menor impacto sobre o resultado final.</p>
# <p style="text-align: justify; text-indent:50px;">O processo de compreensão dos dados, por sua vez, é centrado em operações que visam a elucidar a questão (ou questões) propostas. Assim, considerando um <i>dataset</i> inicial e uma pergunta de negócio a ser respondida, é necessário explorar a relação entre as variáveis, assim como seu grau de correlação com o atributo alvo da pergunta. E é justamente por meio da Análise de Dados que se torna possível soluções mais adequadas e/ou ótimas às perguntas realizadas sobre um <i>dataset</i>.</p>
#
# # <b>3 Metodologia</b>
# <p style="text-align: justify; text-indent:50px;">Para o trabalho, optou-se pelo subconjunto de dados sobre os vinhos tintos. </p>
# <p style="text-align: justify; text-indent:50px;">Como o conjunto de dados é relativamente pequeno, todas as características disponíveis foram utilizadas e considerou-se a variável <i>'quality'</i> como a variável dependente.</p>
# <p style="text-align: justify; text-indent:50px;">Trabalhar com todos os atributos permitiu uma visão mais compreensiva dos dados, com uma análise exploratória ampla que servirá para embasar a construção de algoritmos de predição.</p>
#
# # <b>4 Resultados</b>

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Carregando a base de dados e exibindo alguma informações básicas sobre o <i>dataset</i>:</p>

# %%
import ds_utils as util
dsWineRed = util.getDSWine_RED()
dsWineRed.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
dsWineRed.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
describe = dsWineRed.describe()
describe
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Como pode-se observar nas tabelas acima, o conjunto de dados é formado por 12 atributos numéricos. Destes 12, 11 são variáveis contínuas e apenas a variável <i>quality</i> pode ser considerada categórica.</p>
#
# ---
# ### Para o conjunto de dados escolhido, selecione pelo menos quatro atributos/caracterı́sticas, e faça:
# ---
# ### • Calcule as seguintes medidas para cada um dos quatro atributos:
# ### – Média
# ### – Moda
# ### – Mediana
# ### – Percentis 20, 50 e 70
# ### – Quartis Q1, Q2 e Q3
# ### – Variância
# ### – Desvio padrão

# %%
atributos_selecionados = dsWineRed.columns #todas selecionadas

for att in atributos_selecionados:
    print('\n',att.upper(), '--------------------')
    print('\n* Média: ' + str(dsWineRed[att].mean()))
    print('\n* Mediana: ' + str(dsWineRed[att].median()))
    print('\n* Percentis 20, 50 e 70: ')
    print(dsWineRed[att].quantile([0.2, 0.5, 0.7]));
    print('\n* Quartis Q1, Q2, Q3: ')
    print(dsWineRed[att].quantile([0.25, 0.5, 0.75]));
    print('\n* Variância: ' + str(dsWineRed[att].var()))
    print('\n* Desvio Padrão: ' + str(dsWineRed[att].std()))
# Out:
#  FIXED ACIDITY --------------------
#
# * Média: 8.31963727329581
#
# * Mediana: 7.9
#
# * Percentis 20, 50 e 70:
# 0.2    7.0
# 0.5    7.9
# 0.7    8.9
# Name: fixed acidity, dtype: float64
#
# * Quartis Q1, Q2, Q3:
# 0.25    7.1
# 0.50    7.9
# 0.75    9.2
# Name: fixed acidity, dtype: float64
#
# * Variância: 3.0314163889978167
#
# * Desvio Padrão: 1.7410963181276953
#
#  VOLATILE ACIDITY --------------------
#
# * Média: 0.5278205128205128
#
# * Mediana: 0.52
#
# * Percentis 20, 50 e 70:
# 0.2    0.37
# 0.5    0.52
# 0.7    0.61
# Name: volatile acidity, dtype: float64
#
# * Quartis Q1, Q2, Q3:
# 0.25    0.39
# 0.50    0.52
# 0.75    0.64
# Name: volatile acidity, dtype: float64
#
# * Variância: 0.032062377651551614
#
# * Desvio Padrão: 0.17905970415353537
#
#  CITRIC ACID --------------------
#
# * Média: 0.2709756097560976
#
# * Mediana: 0.26
#
# * Percentis 20, 50 e 70:
# 0.2    0.07
# 0.5    0.26
# 0.7    0.39
# Name: citric acid, dtype: float64
#
# * Quartis Q1, Q2, Q3:
# ...

# %% [markdown]
# ---
# ### - Gere boxplots dos atributos selecionados e identifique a presença ou não de outliers.
# ---

# %%
from sklearn import preprocessing
import pandas as pd
import seaborn as sns

dsWineRed_reduzido = dsWineRed[atributos_selecionados]
min_max_scaler = preprocessing.MinMaxScaler()
dsWineRed_normalizado = pd.DataFrame(min_max_scaler.fit_transform(dsWineRed_reduzido), columns=atributos_selecionados)
dsWineRed_normalizado.iloc[:,0:6].boxplot(figsize=(12,4));

# %%
dsWineRed_normalizado.iloc[:,6:12].boxplot(figsize=(12,4));

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Conforme pode ser observado nos gráficos boxspot acima, há outliers em praticamente todas as características. São destaques neste quesito: 'residual sugar', 'chlorides' e 'sulphates'.</p>
#
# ---
# ### -  Gere histogramas dos atributos e interprete sua distribuição, considerando as classes.
# ---

# %%
dsWineRed_reduzido.hist(figsize=(8,12), bins=50, grid=False);

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">A maioria dos atributos apresenta distribuição diferente da normal. Apenas <i>density</i> parece estar próxima de uma distribuição gaussiana.</p>
#
# ### - Gere scatter plots considerando os atributos dois a dois.

# %%
import matplotlib as mpl
mpl.rc('figure', max_open_warning = 0)

for i, att1 in enumerate(atributos_selecionados):
    for j in range(i+1, len(atributos_selecionados)):
        dsWineRed_normalizado.plot.scatter(x=atributos_selecionados[i], y=atributos_selecionados[j]);

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">A análise dos <i>scatter plots</i> permite inferir graus significativos de correlação entre as variáveis: <i>fixed acidity</i>	e <i>pH</i>; <i>fixed acidity</i>	e <i>citric acid</i>; <i>fixed acidity</i>	e <i>density</i>.</p>
#
# ---
# ### - Para o conjunto completo, calcule as matrizes de Covariância e Correlação
# ---

# %%
dsWineRed.cov()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              3.031416         -0.079851     0.227820
# volatile acidity          -0.079851          0.032062    -0.019272
# citric acid                0.227820         -0.019272     0.037947
# residual sugar             0.281756          0.000484     0.039434
# chlorides                  0.007679          0.000517     0.001869
# free sulfur dioxide       -2.800921         -0.019674    -0.124252
# total sulfur dioxide      -6.482346          0.450426     0.227697
# density                    0.002195          0.000007     0.000134
# pH                        -0.183586          0.006495    -0.016298
# sulphates                  0.054010         -0.007921     0.010328
# alcohol                   -0.114421         -0.038600     0.022815
# quality                    0.174424         -0.056476     0.035612
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
matriz_corr = dsWineRed.corr()
matriz_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import ds_utils as util
util.getCorrHeatMap(dsWineRed, False);

# %% [markdown]
# ---
# ### - Imagine pelo menos 3 perguntas sobre o conjunto de dados e as responda através de medidas de análise de dados.
# ---
#
# ### Perguntas imaginadas:
#
# ### 1) Que atributo está mais próximo de uma distribuição normal?

# %%
std = describe.loc['std'].sort_values()
std
# Out:
# density                  0.001887
# chlorides                0.047065
# pH                       0.154386
# sulphates                0.169507
# volatile acidity         0.179060
# citric acid              0.194801
# quality                  0.807569
# alcohol                  1.065668
# residual sugar           1.409928
# fixed acidity            1.741096
# free sulfur dioxide     10.460157
# total sulfur dioxide    32.895324
# Name: std, dtype: float64

# %%
dsWineRed[std.index[0]].plot.hist(title=std.index[0]);

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Pela tabela acima e análise dos histogramas, fica claro que a variável mais próxima da curva normal é a <i>density</i>.</p>

# %% [markdown]
# ### 2) Que variável está mais correlacionada com o atributo "quality"?

# %%
df_corr_quality = pd.DataFrame(matriz_corr['quality'])
df_corr_quality['corr_abs_value'] = df_corr_quality.iloc[:,0].abs()
df_corr_quality.sort_values(by='corr_abs_value', ascending=False, inplace=True)
df_corr_quality.iloc[1:]
# Out:
#                        quality  corr_abs_value
# alcohol               0.476166        0.476166
# volatile acidity     -0.390558        0.390558
# sulphates             0.251397        0.251397
# citric acid           0.226373        0.226373
# total sulfur dioxide -0.185100        0.185100
# density              -0.174919        0.174919
# chlorides            -0.128907        0.128907
# fixed acidity         0.124052        0.124052
# pH                   -0.057731        0.057731
# free sulfur dioxide  -0.050656        0.050656
# residual sugar        0.013732        0.013732

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Pela tabela acima e análise dos <i>scatter plots</i>, fica claro que a variável com correlação mais forte com a variável algo é a <i>alcohol</i>, com um índice de correlação de 0.476166.</p>

# %% [markdown]
# ### 3) Considerando o atributo "quality" como alvo, qual o par de variáveis independentes seria o melhor candidato ao descarte por serem redundantes?

# %%
df_redundancia = pd.DataFrame(columns=['var1', 'var2', 'corr_value'])
matriz_corr_varindep = matriz_corr.drop(['quality'], axis=0).drop(['quality'], axis=1)
matriz_corr_varindep

for i, att1 in enumerate(matriz_corr_varindep.columns):
    for j in range(i+1, len(matriz_corr_varindep.index)):
        row = {'var1': att1, 'var2': matriz_corr_varindep.index[j], 'corr_value': matriz_corr_varindep.iloc[i,j]}
        #print(row)
        df_redundancia = df_redundancia.append(row, ignore_index=True) 
        
df_redundancia['corr_value_abs'] = df_redundancia['corr_value'].abs()
df_redundancia.sort_values(by='corr_value_abs', ascending=False, inplace=True)
df_redundancia.head(10)
# Out:
#                    var1                  var2  corr_value  corr_value_abs
# 7         fixed acidity                    pH   -0.682978        0.682978
# 1         fixed acidity           citric acid    0.671703        0.671703
# 6         fixed acidity               density    0.668047        0.668047
# 40  free sulfur dioxide  total sulfur dioxide    0.667666        0.667666
# 10     volatile acidity           citric acid   -0.552496        0.552496
# 24          citric acid                    pH   -0.541904        0.541904
# 51              density               alcohol   -0.496180        0.496180
# 38            chlorides             sulphates    0.371260        0.371260
# 23          citric acid               density    0.364947        0.364947
# 30       residual sugar               density    0.355283        0.355283

# %% [markdown]
# <p style="text-align: justify; text-indent:50px;">Pela tabela acima, infere-se que a variável <i>fixed acidity</i> é uma forte candidata a ser retirada do <i>dataset</i> de treinamento em uma eventual redução de dimensionalidade. Como pode-se observar, ela tem uma alta correlação com outras três variáveis independentes, o que sugere uma redundância nos dados.</p>

# %% [markdown]
# # <b>Referências</b>
# <p align="left">
# - Carvalho, André, et al. "Inteligência Artificial–uma abordagem de aprendizado de máquina." Rio de Janeiro: LTC (2011).
# </p>
# <p align="left">
# - Bruce, Andrew, and Peter Bruce. Estatística Prática para Cientistas de Dados. Alta Books, 2019.
# </p>

# %%
#%load_ext notexbook
#%texify
